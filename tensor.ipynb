# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn import preprocessing
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, LeakyReLU
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import shuffle


pd.options.mode.chained_assignment = 'warn'

UNREST_COLUMNS = ["EVENT_ID_CNTY", 
                    "EVENT_DATE", 
                    "EVENT_TYPE", 
                    "REGION", 
                "FATALITIES",
                "TIMESTAMP"]

CASES_COLUMNS = ["iso_code",
                "continent",
                "location", 
                "date", 
                "total_cases", 
                "new_cases", 
                "total_deaths", 
                "reproduction_rate", 
                "hosp_patients", 
                "positive_rate", 
                "stringency_index", 
                "population",
                "median_age",
                "gdp_per_capita",
                "life_expectancy",
            ]

def serialize(dataFrame, column):
    return [x for x in range(len(dataFrame.loc[:, column].unique()))]

def replaceDict(dataFrame, column):
    vals = serialize(dataFrame, column)
    return dict(zip(dataFrame.loc[:, column].unique(), vals))

def multiSearch(df, column, searchTerms):
    if type(searchTerms) is list:
        return df.query(' | '.join(
            [f'{column} == "{term}"' for term in searchTerms]
        ))
    elif type(searchTerms) is str:
        return df.query(f'{column} == "{searchTerms}"')
    else:
        return df.query(f'{column} == {searchTerms}')

def multiContains(df, column, searchTerms):
    if type(searchTerms) is list:
        return df[df.loc[:, column].str.contains('|'.join(searchTerms))]
    else:
        return df[df.loc[:, column].str.contains(searchTerms)]

#Create the training data set of merged PD's and the result
def retrieveTrainingData(isoCodes=None):
    unrest_df = pd.read_csv("./drive/MyDrive/machine-learning/coronavirus_Oct31.csv")
    unrest_df = unrest_df[unrest_df.loc[:, "EVENT_TYPE"] != 'Strategic developments']
 
    covid_cases_df = pd.read_csv("./drive/MyDrive/machine-learning/owid-covid-data.csv")
    covid_cases_df = covid_cases_df[covid_cases_df.loc[:, "iso_code"] != "OWID_WRL"]
    covid_cases_df.dropna() 

    print(unrest_df.EVENT_TYPE.unique())

    unrest_df = unrest_df.loc[:, unrest_df.columns.intersection(UNREST_COLUMNS)]
    covid_cases_df = covid_cases_df.loc[:, covid_cases_df.columns.intersection(CASES_COLUMNS)]

    if (isoCodes == None):
      unrest = unrest_df
      cases = covid_cases_df
    else:
      unrest = multiContains(unrest_df, "EVENT_ID_CNTY", isoCodes)
      cases = multiSearch(covid_cases_df, 'iso_code', isoCodes)

    unrest.loc[:, "EVENT_DATE"] = pd.to_datetime(unrest.loc[:, "EVENT_DATE"])
    cases.loc[:, "date"] = pd.to_datetime(cases.loc[:, "date"]) 

    merge = unrest.merge(cases, how="inner", left_on="EVENT_DATE", right_on="date")

    merge = merge.drop(['EVENT_ID_CNTY'], axis=1)
    merge = merge.drop_duplicates()

    issueType = merge['EVENT_TYPE']
    issueType = issueType.replace(replaceDict(unrest_df, "EVENT_TYPE"))


    merge = merge.drop(['EVENT_TYPE', 'EVENT_DATE', 'REGION', 'iso_code', 'continent', 'location', 'date', 'TIMESTAMP', "FATALITIES"], axis=1).fillna(0)

    return merge, issueType

data, target = retrieveTrainingData()

#convert data to Tensorflow dataset
tensor_data = tf.data.Dataset.from_tensor_slices(
    (
        tf.cast(data.values, tf.float32),
        tf.cast(target, tf.int32)
    )
).shuffle(10, reshuffle_each_iteration=False)

print(tf.data.experimental.cardinality(tensor_data).numpy())

#split data into train and test data
TEST_DIVISOR = 10

def is_test_data(x,y):
  return x % 10 == TEST_DIVISOR #only returns every 10th row

def is_train_data(x,y):
  return not is_test_data(x,y)#returns the other rows

extract_data = lambda x,y:y

train_data = tensor_data.enumerate().filter(is_train_data)
#.map(extract_data).cache()
test_data = tensor_data.enumerate().filter(is_test_data)
#.map(extract_data).cache()

print(train_data)
print(test_data) 

print(tf.data.experimental.cardinality(train_data).numpy())
print(tf.data.experimental.cardinality(test_data).numpy())
# Out:
# Streaming output truncated to the last 5000 lines.
# features:5359 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([2.3800000e+02, 6.7000000e+01, 0.0000000e+00, 2.0500000e+00,
#        0.0000000e+00, 7.0000002e-03, 6.8519997e+01, 3.4813868e+07,
#        3.1900000e+01, 4.9045410e+04, 7.5129997e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5360 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.260000e+02, 1.700000e+01, 1.400000e+01, 9.700000e-01,
#        0.000000e+00, 0.000000e+00, 8.333000e+01, 3.393800e+04,
#        0.000000e+00, 5.686147e+04, 8.497000e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5361 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.9900000e+02, 5.2000000e+01, 0.0000000e+00, 2.2600000e+00,
#        0.0000000e+00, 3.0000000e-03, 6.8059998e+01, 1.4593446e+08,
#        3.9599998e+01, 2.4765953e+04, 7.2580002e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5362 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 4.1669998e+01, 1.5893219e+07,
#        1.6799999e+01, 0.0000000e+00, 5.7400002e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5363 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([3.900000e+01, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 7.778000e+01, 5.106622e+06,
#        3.070000e+01, 3.796071e+04, 7.786000e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5364 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([3.190000e+02, 3.300000e+01, 1.000000e+00, 1.270000e+00,
#        4.600000e+01, 3.200000e-02, 7.870000e+01, 2.078932e+06,
#        4.450000e+01, 3.140084e+04, 8.132000e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5365 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([6.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.4259998e+01, 9.8340000e+04,
#        3.6200001e+01, 2.6382287e+04, 7.3400002e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5366 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.1000000e+01, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 4.2590000e+01, 1.2952209e+07,
#        2.0299999e+01, 1.8542111e+03, 6.9019997e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5367 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([    0.  ,     0.  ,     0.  ,     0.  ,     0.  ,     0.  ,
#            0.  , 42882.  ,     0.  , 36327.23,    78.95], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5368 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([8.6520000e+03, 8.7000000e+01, 1.0000000e+02, 6.6000003e-01,
#        0.0000000e+00, 9.9999998e-03, 5.5560001e+01, 5.1269184e+07,
#        4.3400002e+01, 3.5938375e+04, 8.3029999e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5369 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 5.556000e+01, 1.160164e+06,
#        2.150000e+01, 7.738975e+03, 6.019000e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5370 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.2300000e+02, 1.6000000e+01, 0.0000000e+00, 1.1799999e+00,
#        0.0000000e+00, 5.5000000e-02, 7.5000000e+01, 5.4596430e+06,
#        4.1200001e+01, 3.0155152e+04, 7.7540001e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5371 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.410000e+03, 1.450000e+02, 2.700000e+01, 1.530000e+00,
#        0.000000e+00, 0.000000e+00, 4.352000e+01, 1.009927e+07,
#        4.100000e+01, 4.694928e+04, 8.280000e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5372 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.5000000e+02, 3.4000000e+01, 0.0000000e+00, 2.3499999e+00,
#        0.0000000e+00, 2.4000000e-02, 5.5560001e+01, 5.9308688e+07,
#        2.7299999e+01, 1.2294876e+04, 6.4129997e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# features:5373 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([3
+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6599 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([2.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000000e+01, 2.8737100e+05,
#        3.9799999e+01, 1.6978068e+04, 7.9190002e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6600 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([6.9400000e+02, 1.7200000e+02, 0.0000000e+00, 2.2200000e+00,
#        6.7000000e+01, 5.4000001e-02, 7.9629997e+01, 1.0708982e+07,
#        4.3299999e+01, 3.2605906e+04, 7.9379997e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6601 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([4.4000000e+01, 9.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 8.9809998e+01, 3.2808150e+06,
#        4.2500000e+01, 1.1713895e+04, 7.7400002e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6602 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 3.333000e+01, 9.880020e+05,
#        2.540000e+01, 2.705406e+03, 6.711000e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6603 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.0500000e+02, 1.3000000e+01, 3.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0370003e+01, 6.9484450e+06,
#        4.4700001e+01, 1.8563307e+04, 7.5050003e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6604 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.1510000e+03, 3.6000000e+01, 6.0000000e+00, 1.3900000e+00,
#        1.8600000e+02, 6.3000001e-02, 7.2220001e+01, 5.7922030e+06,
#        4.2299999e+01, 4.6682516e+04, 8.0900002e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6605 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([3.000e+00, 2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 1.641e+05, 4.170e+01, 0.000e+00, 7.888e+01],
#       dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6606 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([2.1000000e+01, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 9.2589996e+01, 1.0847904e+07,
#        2.7600000e+01, 1.4600861e+04, 7.4080002e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6607 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.0400000e+02, 2.3000000e+01, 0.0000000e+00, 2.3800001e+00,
#        0.0000000e+00, 7.1999997e-02, 6.6669998e+01, 4.1052680e+06,
#        4.4000000e+01, 2.2669797e+04, 7.8489998e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6608 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([4.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.4029850e+06,
#        2.2400000e+01, 2.2604873e+04, 5.8740002e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6609 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([2.1000000e+02, 1.4000000e+01, 6.0000000e+00, 1.5000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.9629999e+01, 1.0233440e+08,
#        2.5299999e+01, 1.0550206e+04, 7.1989998e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6610 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#        0.000000e+00, 0.000000e+00, 6.574000e+01, 6.486201e+06,
#        2.760000e+01, 7.292458e+03, 7.332000e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6611 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([7.2000e+01, 2.5000e+01, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 4.8865e+04, 0.0000e+00, 0.0000e+00,
#        8.0670e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6612 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([2.6700000e+02, 9.0000000e+00, 0.0000000e+00, 1.3400000e+00,
#        2.4000000e+01, 9.6000001e-02, 5.0000000e+01, 1.3265390e+06,
#        4.2700001e+01, 2.9481252e+04, 7.8739998e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6613 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([1.9900000e+02, 3.1000000e+01, 3.0000000e+00, 2.9000001e+00,
#        0.0000000e+00, 0.0000000e+00, 9.3519997e+01, 1.7643060e+07,
#        2.8100000e+01, 1.0581936e+04, 7.7010002e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# features:6614 target:(<tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([3.4200000e+02, 1.0400000e+02, 0.0000000e+00, 2.4500000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.5560001e+01, 1.9116208e+07,
#        3.5400002e+01, 2.2767037e+04, 8.0180000e+01], dtype=float32)>, <tf.Tensor: shape=(), dtype=int32, numpy=0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-c218e1ae0e46> in <module>()
#     125 #.map(extract_data).cache()
#     126
# --> 127 for features_tensor, target_tensor in train_data:
#     128     print(f'features:{features_tensor} target:{target_tensor}')
#     129
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     745   def __next__(self):
#     746     try:
# --> 747       return self._next_internal()
#     748     except errors.OutOfRangeError:
#     749       raise StopIteration
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     731           self._iterator_resource,
#     732           output_types=self._flat_output_types,
# --> 733           output_shapes=self._flat_output_shapes)
#     734
#     735       try:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    2574       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2575         _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
# -> 2576         "output_shapes", output_shapes)
#    2577       return _result
#    2578     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
